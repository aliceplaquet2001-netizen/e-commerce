# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from io import StringIO
import os

# ====================== CHARGEMENT DIRECT DES 10 CSV ======================

csv_01 = """nb_evenements,date_debut,date_fin,nb_utilisateurs_uniques,nb_sessions
4295584,2020-11-01,2021-01-31,270154,360129"""
df_global = pd.read_csv(StringIO(csv_01))

csv_02 = """event_name,nb_evenements,nb_utilisateurs,pourcentage
page_view,1350428,269792,31.44
user_engagement,1058721,213004,24.65
scroll,493072,138098,11.48
view_item,386068,61252,8.99
session_start,354970,267116,8.26
first_visit,257462,257314,5.99
view_promotion,190104,102443,4.43
add_to_cart,58543,12545,1.36
begin_checkout,38757,9715,0.9
select_item,31007,13180,0.72
view_search_results,26172,14449,0.61
add_shipping_info,19722,9714,0.46
add_payment_info,13899,5751,0.32
select_promotion,9450,8164,0.22
purchase,5692,4419,0.13
click,1446,1010,0.03
view_item_list,71,44,0.0"""
df_events = pd.read_csv(StringIO(csv_02))

csv_03 = """nb_utilisateurs,view_to_add_pct,add_to_checkout_pct,checkout_to_purchase_pct
270154,4.64,3.6,1.64"""
df_funnel = pd.read_csv(StringIO(csv_03))

csv_04 = """nb_achats,CA_total,panier_moyen,revenu_par_utilisateur
5692,362165.0,63.63,81.96"""
df_kpis = pd.read_csv(StringIO(csv_04))

csv_05 = """item_name,nb_ventes,CA_produit,prix_moyen
Google Zip Hoodie F/C,256,13788.0,53.86
Google Crewneck Sweatshirt Navy,225,10714.0,47.62
Google Men's Tech Fleece Grey,123,9965.0,81.02
Google Badge Heavyweight Pullover Black,184,9712.0,52.78
Super G Unisex Joggers,285,9529.0,33.44
Google Crewneck Sweatshirt Green,177,8382.0,47.36
Google Sherpa Zip Hoodie Charcoal,105,6397.0,60.92
Google Men's Puff Jacket Black,63,6187.0,98.21
Google Men's Tech Fleece Vest Charcoal,77,5549.0,72.06
Google Women's Puff Jacket Black,56,5313.0,94.88"""
df_products = pd.read_csv(StringIO(csv_05))

csv_06 = """device_type,nb_sessions,CA_total,panier_moyen,pourcentage_sessions
desktop,3226,208815.0,64.73,56.68
mobile,2355,146768.0,62.32,41.37
tablet,111,6582.0,59.3,1.95"""
df_device = pd.read_csv(StringIO(csv_06))

csv_07 = """pays,nb_achats,CA_total,panier_moyen,pourcentage_CA
United States,2481,160573.0,64.72,43.59
India,530,34986.0,66.01,9.31
Canada,466,32799.0,70.38,8.19
United Kingdom,177,11458.0,64.73,3.11
Spain,131,7681.0,58.63,2.3
France,119,6650.0,55.88,2.09
China,101,6623.0,65.57,1.77
Japan,86,5752.0,66.88,1.51
Turkey,76,5345.0,70.33,1.34
Germany,87,5288.0,60.78,1.53"""
df_country = pd.read_csv(StringIO(csv_07))

csv_08 = """medium,source,nb_achats,CA_total,panier_moyen
organic,google,1454,95775.0,65.87
(none),(direct),1251,79650.0,63.67
(data deleted),(data deleted),830,50064.0,60.32
referral,shop.googlemerchandisestore.com,701,46521.0,66.36
referral,<Other>,557,37000.0,66.43
<Other>,<Other>,606,35470.0,58.53
cpc,google,166,9056.0,54.55
organic,<Other>,118,8232.0,69.76
(data deleted),<Other>,9,397.0,44.11"""
df_traffic = pd.read_csv(StringIO(csv_08))

csv_09 = """jour_semaine,nb_achats,CA_total,panier_moyen
Monday,874,61870.0,70.79
Tuesday,991,61970.0,62.53
Wednesday,982,63937.0,65.11
Thursday,829,49691.0,59.94
Friday,981,59281.0,60.43
Saturday,604,38412.0,63.6
Sunday,431,27004.0,62.65"""
df_day = pd.read_csv(StringIO(csv_09))

csv_10 = """heure,nb_achats,CA_total,panier_moyen
0,234,17010,72.69
1,225,14755,65.58
2,236,14465,61.29
3,230,16400,71.3
4,232,14491,62.46
5,285,16595,58.23
6,256,17430,68.09
7,228,13160,57.72
8,245,15209,62.08
9,224,13225,59.04
10,223,14809,66.41
11,201,13728,68.3
12,225,12083,53.7
13,232,14119,60.86
14,227,15780,69.52
15,220,15160,68.91
16,275,17335,63.04
17,240,16134,67.22
18,232,12701,54.75
19,242,14400,59.5
20,232,15315,66.01
21,237,15512,65.45
22,290,18253,62.94
23,221,14096,63.78"""
df_hour = pd.read_csv(StringIO(csv_10))

print("✅ Les 10 fichiers CSV ont été chargés directement dans le notebook !")

# ====================== CRÉATION DES GRAPHIOUES ======================

# 1. Funnel interactif
fig_funnel = go.Figure(go.Funnel(
    y=["View Item", "Add to Cart", "Begin Checkout", "Purchase"],
    x=[100, df_funnel['view_to_add_pct'].iloc[0],
       df_funnel['add_to_checkout_pct'].iloc[0],
       df_funnel['checkout_to_purchase_pct'].iloc[0]],
    textinfo="value+percent initial+percent previous",
    marker=dict(color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"])
))
fig_funnel.update_layout(title="Funnel de Conversion avec Taux de Drop-off", height=600)
fig_funnel.show()

# 2. Treemap Top Produits
fig_treemap = px.treemap(df_products.head(15), path=['item_name'], values='CA_produit',
                         title="Top 15 Produits par Revenu")
fig_treemap.show()

# 3. CA par Heure
fig_hour = px.bar(df_hour, x='heure', y='CA_total', title="Chiffre d'Affaires par Heure")
fig_hour.show()

# 4. CA par Device
fig_device = px.bar(df_device, x='device_type', y='CA_total', title="CA par Device")
fig_device.show()

# 5. CA par Pays (Top 10)
fig_country = px.bar(df_country.head(10), x='pays', y='CA_total', title="CA par Pays (Top 10)")
fig_country.show()

# 6. CA par Canal
fig_traffic = px.bar(df_traffic, x='medium', y='CA_total', title="CA par Canal d'Acquisition")
fig_traffic.show()

# ====================== SAUVEGARDE DANS visualizations/ ======================
os.makedirs('visualizations', exist_ok=True)

fig_funnel.write_html("visualizations/01_funnel_interactif.html")
fig_treemap.write_html("visualizations/02_top_products_treemap.html")
fig_hour.write_html("visualizations/03_heure.html")
fig_device.write_html("visualizations/04_device.html")
fig_country.write_html("visualizations/05_pays.html")
fig_traffic.write_html("visualizations/06_canal.html")

print("🎉 Tous les graphiques interactifs ont été créés et sauvegardés dans le dossier visualizations/")
# Out:
# ✅ Les 10 fichiers CSV ont été chargés directement dans le notebook !
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
